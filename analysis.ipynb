# %%
import pandas as pd

# %%
data=pd.read_csv("/home/victor/Documents/CasesStudy_ChurnRate/sujet_B_data_client_churn.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0           0  7590-VHVEG  Female              0     Yes         No       1
# 1           1  5575-GNVDE    Male              0      No         No      34
# 2           2  3668-QPYBK    Male              0      No         No       2
# 3           3  7795-CFOCW    Male              0      No         No      45
# 4           4  9237-HQITU  Female              0      No         No       2
#
#   PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 0           No  No phone service             DSL  ...               No
# 1          Yes                No             DSL  ...              Yes
# 2          Yes                No             DSL  ...               No
# 3           No  No phone service             DSL  ...              Yes
# 4          Yes                No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
data.shape
# Out:
# (7043, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7043 non-null   int64
#  1   customerID        7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      1409 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       5517 non-null   object
#  14  StreamingTV       5517 non-null   object
#  15  StreamingMovies   5517 non-null   object
# ...

# %%
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 770 entries, 2 to 7038
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        770 non-null    int64
#  1   customerID        770 non-null    object
#  2   gender            770 non-null    object
#  3   SeniorCitizen     770 non-null    int64
#  4   Partner           770 non-null    object
#  5   Dependents        770 non-null    object
#  6   tenure            770 non-null    int64
#  7   PhoneService      770 non-null    object
#  8   MultipleLines     770 non-null    object
#  9   InternetService   770 non-null    object
#  10  OnlineSecurity    770 non-null    object
#  11  OnlineBackup      770 non-null    object
#  12  DeviceProtection  770 non-null    object
#  13  TechSupport       770 non-null    object
#  14  StreamingTV       770 non-null    object
#  15  StreamingMovies   770 non-null    object
# ...
